# %%
terraform destroy  -input=false -auto-approve
# Out:
# hpegl_vmaas_instance.didou: Refreshing state... [id=171]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   - destroy
#
# Terraform will perform the following actions:
#
#   # hpegl_vmaas_instance.didou will be destroyed
#   - resource "hpegl_vmaas_instance" "didou" {
#       - cloud_id           = 1 -> null
#       - containers         = [
#           - {
#               - container_type = [
#                   - {
#                       - name = "vanilla-centos7-node"
#                     },
#                 ]
#               - external_fqdn  = "didou.localdomain"
#               - hostname       = "didou"
#               - id             = 171
#               - ip             = "172.17.70.20"
#               - max_cores      = 1
#               - max_memory     = 4294967296
#               - max_storage    = 16106127360
#               - name           = "didou_171"
# ...
