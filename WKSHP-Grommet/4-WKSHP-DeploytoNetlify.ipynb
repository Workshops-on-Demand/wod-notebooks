# %% [markdown]
# ## Lab 4: Deploy your App to Netlify
#
# This Jupyter notebook will drive you through the following steps :
#
# - Sign up for a Netlify account using GitHub account
# - Link your GitHub repository to Netlify
# - Edit deployment settings
# - Deploy your application on the internet
#
# ### Netlify?
# Netlify is simply used for hosting static sites. Another alternative to static site hosting is GitHub pages.
#
# - Netlify allows user to generate a custom URL for a project under Netlify.app domain name e.g `studentxxx.netlify.app`
# - It is possible to connect own custom domain e.g `mywebsite.com`, set up a CNAME, and A-Records on Netlify. More information from [Netlify website](https://www.netlify.com/blog/2020/03/26/how-to-set-up-netlify-dns-custom-domains-cname-and-a-records/)
# - It is possible to drag and drop a folder containing project HTML, CSS, JS into Netlify for manual deployment using Netlify drop (screenshot below).
# - For automatic deployment, a user can connect a GitHub repository to Netlify and have it automatically trigger new deployments with new repository commits in a continuous integration approach.
#
#
# ### Signup
#
# Sign up for [Netlify](https://app.netlify.com/login) account using your GitHub account
#
# ![Netlify login](Pictures/netlify-login.png)
#
# After you sign up, you will be redirected to Netlify account site section.
#
# ### Link your GitHub repository to netlify
#
# Click on New site from git to link your GitHub repository to netlify
#
# Let us proceed with New Site from GitHub option
#
# Choose the Git provider where your site’s source code is hosted and select the repository to grant access to netlify.
#
# ![Netlify add new site](Pictures/netlify-add-new-site.png)
#
# Select `Deploy with GitHub`
#
# ![Deploy with GiHub](Pictures/netlify-deploy-with-github.png)
#
# Add your repository e.g `studentxxx`
#
# ![Search for project](Pictures/netlify-search-for-project.png)
#
# ### Check deployment settings and deploy
#
# On next screen, Chose `Site name` e.g `studentxxx` and check availability.
#
# ![Check site name availability](Pictures/netlify-check-availability.png)
#
# Proceed to deployment by Clicking `Deploy` button at the bottom of the page if your chosen `Site name` above is available.
#
# ![Netlify deploy site](Pictures/netlify-deploy-site.png)
#
# You can see your site url at the top of the page. Click it to go to your deployed Netlify site.
#
# ![Deployed Netlify site link](Pictures/netlify-deployed-site-link.png)
#
# By default, auto publish will be turned on, if you make any changes to your GitHub source code, netlify will auto deploy your site.
#
# ![Deployed Netlify site](Pictures/netlify-deployed-site.png)
#
# ## Congratulations
#
#
# You have successfully designed your app using [grommet designer](https://designer.grommet.io/) and deployed it to [Netlify](https://student{{STDID}}.netlify.app).

# %% [markdown]
# # Time to wrap up
# You can now move to the conclusion of this workshop !
#
# * [Conclusion](5-WKSHP-Conclusion.ipynb)
