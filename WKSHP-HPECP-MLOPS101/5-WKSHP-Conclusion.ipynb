# %% [markdown]
# {{ BRANDINGLOGO }}
#
# # Thank you for visiting the Hack Shack
#
# Powered by [{{ BRANDING }} Community Team](hpedev.io)
#
# {% if MODEWS == 'CHLG' %}
# # Thank you for participating to our software challenge
# {% endif %}
#
#
# # Conclusion
#
# In the following workshop, you have learned about the MLOPS Basics.Using an example  predicting chances of diabetes amongst Pima Indians, you have beren l looking at the steps to build an **ML pipeline** that implements a basic end-to-end data science machine learning workflow process and that brings models to production. All of this in a single platform: **HPE Ezmeral ML Ops**.
#
#
# For more documentation on the HPE Ezmeral MLOPS see [HPE Ezmeral MLOPS](https://docs.containerplatform.hpe.com/53/reference/universal-concepts/About_HPE_Ezmeral_ML_Ops.html)
#
#
# Congratulations and Thank you for your time in learning about the HPE Ezmeral MLOPS!
#
#
# {% if MODEWS == 'CHLG' %}
# # The challenge is not over yet
# In order to complete the challenge, you must take the [quiz]({{ SURVEYCHALURL }}). Only then will you get a chance to become a winner! Please note that you must be present at the Hack Shack Celebration party to win. Refer to the Terms and Conditions for details.
# {% endif %}
# # Final steps
# Please take a moment to fill out our [survey]({{ SURVEYURL }}).
#
# And make sure you use `File -> Log Out menu` to terminate your workshop session.
#
# # Thank you
# ![ThankYou](Pictures/grommet.JPG)
